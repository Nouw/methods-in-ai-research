# %%
from methods_in_ai_research.processing import preprocess
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from methods_in_ai_research.processing import preprocess
#
# ModuleNotFoundError: No module named 'methods_in_ai_research'
